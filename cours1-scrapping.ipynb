# %% [markdown]
# ## Requests - scrapping

# %%
import requests

# %%
page = "https://www.beerwulf.com/fr-fr/p/bieres/desperados-fut-2l"
response = requests.get(page)

# %%
# html de toute la page
response.text
# Out:
# '\r\n<!doctype html>\r\n<html class="no-js" lang="fr-FR"\r\n      data-original-lang="fr-FR"\r\n      data-rendered-at="Thu, 26 Sep 2019 13:56:20 GMT"\r\n      data-sku-ui-url="/fr-FR/api/product/get/ui"\r\n      data-release="1.7.15-906-1"\r\n      data-datalayer="{&quot;page&quot;:{&quot;type&quot;:&quot;product&quot;,&quot;category1&quot;:&quot;Beers&quot;,&quot;category2&quot;:null,&quot;category3&quot;:null,&quot;language&quot;:&quot;fr-FR&quot;,&quot;country&quot;:&quot;FR&quot;,&quot;currency&quot;:null},&quot;user&quot;:null}"\r\n      data-datalayer-url="/fr-FR/api/gtm/dataLayer">\r\n<head>\r\n    \r\n    <meta charset="utf-8" />\r\n\r\n    <title>Desperados TORP - F&#251;t de 2L  | Achat bi&#232;re en ligne | Beerwulf</title>\r\n\r\n    <!-- Website Meta information -->\r\n    <meta property="og:url" content="https://www.beerwulf.com/fr-fr/p/bieres/desperados-fut-2l" />\r\n    <meta name="twitter:card" content="summary_large_image">\r\n    <meta name="twitter:site" content="@BeerwulfWebshop">\r\n    <meta name="twitter:creator" content="@BeerwulfWebshop">\r\n    <meta name="description" content="Acheter Desperados TORP - F&#251;t de 2Len ligne ✓  Livraison gratuite ✓ Pack original ✓ Coffrets personnalis&#233;s" />\r\n    <meta name="title" content="Desperados TORP - F&#251;t de 2L  | Achat bi&#232;re en ligne" />\r\n    <meta property="og:description" content="Acheter Desperados TORP - F&#251;t de 2Len ligne ✓  Livraison gratuite ✓ Pack original ✓ Coffrets personnalis&#233;s" />\r\n    <meta name="twitter:description" content="Acheter Desperados TORP - F&#251;t de 2Len ligne ✓  Livraison gratuite ✓ Pack original ✓ Coffrets personnalis&#233;s">\r\n    <meta property="og:type" content="product" />\r\n    <meta property="og:title" content="Desperados TORP - F&#251;t de 2L  | Achat bi&#232;re en ligne" />\r\n    <meta name="twitter:title" content="Desperados TORP - F&#251;t de 2L  | Achat bi&#232;re en ligne">\r\n    <meta property="og:image" content="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/generic_sharing_fb_fr.jpg?w=1200&amp;h=630" />\r\n    <meta name="twitter:image" content="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/generic_sharing_fb_fr.jpg?w=1200&amp;h=630" />\r\n\r\n    <!-- Force a server reload on every request due to the shopping cart restoring -->\r\n    <meta http-equiv="cache-control" content="no-cache, must-revalidate, post-check=0, pre-check=0" />\r\n    <meta http-equiv="cache-control" content="max-age=0" />\r\n    <meta http-equiv="expires" content="0" />\r\n    <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT" />\r\n    <meta http-equiv="pragma" content="no-cache" />\r\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\r\n\r\n    <link rel="stylesheet" href="/static/dist/assets/css/app.css?cb=1.7.15-906-1">\r\n    <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\r\n    <link rel="icon" type="image/png" href="/favicon-32x32.png" sizes="32x32">\r\n    <link rel="icon" type="image/png" href="/favicon-16x16.png" sizes="16x16">\r\n    <link rel="manifest" href="/manifest.json">\r\n    <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#333333">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <meta name="theme-color" content="#ffffff">\r\n\r\n        <meta name="robots" content="index">\r\n\r\n        <script id="gtm-model">\r\n            window[\'noBlocker\'] = true;\r\n            window.dataLayer = window.dataLayer || [];\r\n        </script>\r\n\r\n    <link rel="alternate" href="https://www.beerwulf.com/de-at/p/biere/desperados-2l-fass" hreflang="de-AT"/>\r\n    <link rel="alternate" href="https://www.beerwulf.com/de-ch/p/biere/desperados-2l-fass" hreflang="de-CH"/>\r\n    <link rel="alternate" href="https://www.beerwulf.com/de-de/p/biere/desperados-2l-fass" hreflang="de-DE"/>\r\n    <link rel="alternate" href="https://www.beerwulf.com/en-gb/p/b ...

# %%
# Extraction par tâtonnement
begin = '<span class="price">'
idx = response.text.index(begin)
response.text[idx+len(begin):idx+100].split('<')[0]
# Out:
# '€ 10,70'

# %% [markdown]
# ## BeautifulSoup - mise en forme des données

# %%
from bs4 import BeautifulSoup

# %%
html = """
<title>Helloooo</title>
<ul>
<li>Item 1</li>
<li>Item 2</li>
</ul>
"""

# %%
#soup contient tout le document
soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <html><head><title>Helloooo</title>
# </head><body><ul>
# <li>Item 1</li>
# <li>Item 2</li>
# </ul>
# </body></html>

# %%
#find renvoie la première balise trouvée
titre = soup.find('title')
titre
# Out:
# <title>Helloooo</title>

# %%
titre.contents
# Out:
# ['Helloooo']

# %%
#soup.find_all('li', class="italic")

# %% [markdown]
# ## Application au site scrappé

# %%
beersoup = BeautifulSoup(response.text, 'lxml')

# %%
# On extrait le span qui a la classe "price"
beersoup.select('span.price')
# Out:
# [<span class="price">€ 10,70</span>]

# %%
# [0] pour sélectionner le premier prix trouvé et text pour le contenu de la balise
beersoup.select('span.price')[0].text
# Out:
# '€ 10,70'

# %%
price = beersoup.select('span.price')[0].text
print(price)
# Out:
# € 10,70

# %%
beersoup.find('dt', text="Contenu").find_next_sibling()
# Out:
# <dd class="small-6 medium-9 columns">200cl</dd>

# %%
def get_soup_from_url(url):
    page = requests.get(url)
    return BeautifulSoup(page.text, "lxml")

def extract_beer_infos(url):
    soup = get_soup_from_url(url)
    
    #Extract price
    price = beersoup.select('span.price')[0].text
    price = float(price[2:].replace(',','.')) #'€ 7,29' => '7.29'
    
    #Extract volume
    volume = soup.find('dt', text='Contenu').find_next_sibling().text
    volume = int(volume[:-2])
    
    #Extract note
    note = soup.find('div', class_="stars")
    note = int(note.attrs['data-percent'])
    
    #Extract EBC
    #ebc = soup.find('div', class_='ebc')
    #children = ebc.find_all('div', class_="active")
    #position = ebc.find_all('div').index(active)
    
    #Structure infos
    infos = {
        'price': price,
        'volume': volume
    }
    return infos

extract_beer_infos(page)
# Out:
# {'price': 10.7, 'volume': 200}

# %%
# requests ne permet pas de trouver les balises qui apparaissent après le chargement de la page (avec du js ou autre)
# on peut utiliser selenium dans ce cas par exemple
