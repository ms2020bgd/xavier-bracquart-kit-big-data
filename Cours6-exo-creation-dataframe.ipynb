# %% [markdown]
# # Cours 6 - Exercice - Création de dataframe
#
# INFMDI721 - Cours - 07/11/2019

# %% [markdown]
# À partir des datasets population_communes.csv et surface_departements.csv, créer un nouveau dataset qui contient une ligne par département, avec ces colonnes:
#
#     - la somme des "Population municipale" du département
#     - la somme des "Population totale" du département (pour l'explication de la distinction entre "Population municipale" et "Population totale", voir: https://www.insee.fr/fr/metadonnees/definition/c1270)
#     - la part (en pourcentage) de la population municipale par rapport à la population totale
#     - la part (en pourcentage) de la population (municipale) du département au sein de sa région
#     - la densité de la population (municipale) en nb d'habitants / km2
#
# (Le dataset final devrait ressembler à result-exo-cc.csv)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Chargement des datasets

# %%
pop = pd.read_csv("inputs/population_communes.csv")
pop.head()
# Out:
#   Code département  Code canton  Code arrondissement  Code région  \
# 0               64         27.0                    3           75
# 1               64         27.0                    3           75
# 2               55         10.0                    2           44
# 3               55         10.0                    2           44
# 4               60         11.0                    1           32
#
#   Nom de la commune  Code commune    Nom de la région               variable  \
# 0              Aast             1  Nouvelle-Aquitaine      Population totale
# 1              Aast             1  Nouvelle-Aquitaine  Population municipale
# 2        Abainville             1           Grand Est      Population totale
# 3        Abainville             1           Grand Est  Population municipale
# 4         Abancourt             1     Hauts-de-France      Population totale
#
#    value
# 0    184
# 1    177
# 2    310
# 3    305
# 4    658

# %%
area = pd.read_csv("inputs/surface_departements.csv")
area.head()
# Out:
#   code_insee               nom  surf_km2
# 0        974        La Réunion    2505.0
# 1         11              Aude    6343.0
# 2         43       Haute-Loire    5003.0
# 3         13  Bouches-du-Rhône    5247.0
# 4         47    Lot-et-Garonne    5385.0

# %% [markdown]
# ## Création du dataframe

# %%
df = pd.DataFrame(columns=["Population municipale","Population totale","Population municipale %","Population municipale / région","Densité"])
df.head()
# Out:
# Empty DataFrame
# Columns: [Population municipale, Population totale, Population municipale %, Population municipale / région, Densité]
# Index: []

# %% [markdown]
# ## Calcul des populations

# %%
df["Population municipale"] = pop[pop["variable"] == "Population municipale"].groupby("Code département").agg({"value":"sum"})["value"]
df["Population totale"] = pop[pop["variable"] == "Population totale"].groupby("Code département").agg({"value":"sum"})["value"]
df["Population municipale %"] = df["Population municipale"] / df["Population totale"]

# %%
df.head()
# Out:
#                   Population municipale  Population totale  \
# Code département
# 01                               638425             655171
# 02                               536136             549587
# 03                               339384             349336
# 04                               162565             167331
# 05                               141107             146148
#
#                   Population municipale % Population municipale / région  \
# Code département
# 01                               0.974440                            NaN
# 02                               0.975525                            NaN
# 03                               0.971512                            NaN
# 04                               0.971518                            NaN
# 05                               0.965508                            NaN
#
#                  Densité
# Code département
# 01                   NaN
# 02                   NaN
# 03                   NaN
# 04                   NaN
# 05                   NaN

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#   Code département  Population municipale  Population totale  \
# 0               01                 638425             655171
# 1               02                 536136             549587
# 2               03                 339384             349336
# 3               04                 162565             167331
# 4               05                 141107             146148
#
#    Population municipale % Population municipale / région Densité
# 0                 0.974440                            NaN     NaN
# 1                 0.975525                            NaN     NaN
# 2                 0.971512                            NaN     NaN
# 3                 0.971518                            NaN     NaN
# 4                 0.965508                            NaN     NaN

# %% [markdown]
# ## Calcul population département / population région

# %%
region_pop = pop.groupby(["Code département","Code région"]).sum().groupby("Code région").transform("sum")["value"]
region_pop.index = region_pop.index.droplevel(1)

# %%
df["Population municipale / région"] = df["Population municipale"] / region_pop
df.head()
# Out:
#   Code département  Population municipale  Population totale  \
# 0               01                 638425             655171
# 1               02                 536136             549587
# 2               03                 339384             349336
# 3               04                 162565             167331
# 4               05                 141107             146148
#
#    Population municipale %  Population municipale / région     Densité
# 0                 0.974440                             NaN  110.377766
# 1                 0.975525                             NaN   72.343274
# 2                 0.971512                             NaN   45.993224
# 3                 0.971518                             NaN   23.246818
# 4                 0.965508                             NaN   24.768650

# %% [markdown]
# La division ne fonctionne pas. Il faut transformer les données au préalable.

# %% [markdown]
# ## Calcul densité

# %%
df = df.merge(area.rename(columns={"code_insee":"Code département"}))
df.head()
# Out:
#   Code département  Population municipale  Population totale  \
# 0               01                 638425             655171
# 1               02                 536136             549587
# 2               03                 339384             349336
# 3               04                 162565             167331
# 4               05                 141107             146148
#
#    Population municipale % Population municipale / région     Densité  \
# 0                 0.974440                            NaN  110.377766
# 1                 0.975525                            NaN   72.343274
# 2                 0.971512                            NaN   45.993224
# 3                 0.971518                            NaN   23.246818
# 4                 0.965508                            NaN   24.768650
#
#                        nom  surf_km2
# 0                      Ain    5784.0
# 1                    Aisne    7411.0
# 2                   Allier    7379.0
# 3  Alpes-de-Haute-Provence    6993.0
# 4             Hautes-Alpes    5697.0

# %%
df["Densité"] = df["Population municipale"]/df["surf_km2"]
df.drop(['nom', 'surf_km2'], axis=1, inplace=True)
df.head()
# Out:
#   Code département  Population municipale  Population totale  \
# 0               01                 638425             655171
# 1               02                 536136             549587
# 2               03                 339384             349336
# 3               04                 162565             167331
# 4               05                 141107             146148
#
#    Population municipale % Population municipale / région     Densité
# 0                 0.974440                            NaN  110.377766
# 1                 0.975525                            NaN   72.343274
# 2                 0.971512                            NaN   45.993224
# 3                 0.971518                            NaN   23.246818
# 4                 0.965508                            NaN   24.768650

# %%
pop[pop["variable"] == "Population municipale"].groupby("Code région").agg({"value":"sum"})["value"]
# Out:
# Code région
# 1       394110
# 2       376480
# 3       269352
# 4       852924
# 11    12117132
# 24     2577866
# 27     2818338
# 28     3335929
# 32     6006870
# 44     5555186
# 52     3737632
# 53     3306529
# 75     5935603
# 76     5808435
# 84     7916889
# 93     5021928
# 94      330455
# Name: value, dtype: int64

# %%
pop[pop["variable"] == "Population municipale"].groupby(["Code région", "Code département"]).agg({"value":"sum"})
# Out:
#                                 value
# Code région Code département
# 1           971                394110
# 2           972                376480
# 3           973                269352
# 4           974                852924
# 11          75                2190327
#             77                1397665
#             78                1431808
#             91                1287330
#             92                1603268
#             93                1606660
#             94                1378151
#             95                1221923
# 24          18                 307110
#             28                 433929
#             36                 223505
#             37                 606223
#             41                 332769
#             45                 674330
# 27          21                 533213
#             25                 538549
#             39                 260517
#             58                 209161
#             70                 237242
#             71                 555023
#             89                 340544
#             90                 144089
# 28          14                 693679
#             27                 602825
#             50                 498362
#             61                 285308
# ...                               ...
# 76          30                 742006
#             31                1348183
#             32                 190664
#             34                1132481
#             46                 173347
#             48                  76422
#             65                 227829
#             66                 474369
#             81                 386448
#             82                 256897
# 84          01                 638425
#             03                 339384
#             07                 325157
#             15                 145969
#             26                 508006
#             38                1252912
#             42                 761997
#             43                 227339
#             63                 650700
#             69                1835903
#             73                 429681
#             74                 801416
# 93          04                 162565
#             05                 141107
#             06                1083704
#             13                2019717
#             83                1055821
#             84                 559014
# 94          2A                 154303
#             2B                 176152
#
# [100 rows x 1 columns]

# %%
df["Population municipale / région"] = df["Population municipale"] / pop[pop["variable"] == "Population municipale"].groupby("Code région").agg({"value":"sum"})["value"]
df.head()
# Out:
#                   Population municipale  Population totale  \
# Code département
# 01                               638425             655171
# 02                               536136             549587
# 03                               339384             349336
# 04                               162565             167331
# 05                               141107             146148
#
#                   Population municipale %  Population municipale / région  \
# Code département
# 01                               0.974440                             NaN
# 02                               0.975525                             NaN
# 03                               0.971512                             NaN
# 04                               0.971518                             NaN
# 05                               0.965508                             NaN
#
#                  Densité
# Code département
# 01                   NaN
# 02                   NaN
# 03                   NaN
# 04                   NaN
# 05                   NaN

# %%
df["Densité"] = df["Population totale"] / area["surf_km2"]
df.head()
# Out:
#                   Population municipale  Population totale  \
# Code département
# 01                               638425             655171
# 02                               536136             549587
# 03                               339384             349336
# 04                               162565             167331
# 05                               141107             146148
#
#                   Population municipale %  Population municipale / région  \
# Code département
# 01                               0.974440                             NaN
# 02                               0.975525                             NaN
# 03                               0.971512                             NaN
# 04                               0.971518                             NaN
# 05                               0.965508                             NaN
#
#                   Densité
# Code département
# 01                    NaN
# 02                    NaN
# 03                    NaN
# 04                    NaN
# 05                    NaN
